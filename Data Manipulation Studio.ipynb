# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np

balt= pd.read_csv("dataset/baltimore_9-24-2016_9-30-2017.csv")
bos = pd.read_csv("dataset/boston_9-24-2016_9-30-2017.csv")
new = pd.read_csv("dataset/new-york_9-24-2016_9-30-2017.csv")
phil = pd.read_csv('dataset/philadelphia_9-24-2016_9-30-2017.csv')

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
for col in balt.columns:
    pct_missing = np.mean(balt[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
for col in bos.columns:
    pct_missing = np.mean(bos[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
for col in new.columns:
    pct_missing = np.mean(new[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
for col in phil.columns:
    pct_missing = np.mean(phil[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 87%
# Item Size - 7%
# Color - 81%
# Environment - 100%
# Unit of Sale - 78%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 79%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 21%
# Color - 100%
# Environment - 100%
# Unit of Sale - 81%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
balt["Type"] = balt["Type"].fillna("Conventional")
balt.head()
# Out:
#   Commodity Name  City Name          Type       Package      Variety  \
# 0       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 1       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 2       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 3       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 4       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
#
#   Sub Variety  Grade        Date  Low Price  High Price  ...  Color  \
# 0         NaN    NaN  04/29/2017        270       280.0  ...    NaN
# 1         NaN    NaN  05/06/2017        270       280.0  ...    NaN
# 2         NaN    NaN  09/24/2016        160       160.0  ...    NaN
# 3         NaN    NaN  09/24/2016        160       160.0  ...    NaN
# 4         NaN    NaN  11/05/2016         90       100.0  ...    NaN
#
#    Environment Unit of Sale  Quality Condition Appearance  Storage Crop  \
# 0          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 1          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 2          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 3          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 4          NaN          NaN      NaN       NaN        NaN      NaN  NaN
#
#    Repack  Trans Mode
# 0       E         NaN
# 1       E         NaN
# 2       N         NaN
# 3       N         NaN
# 4       N         NaN
#
# [5 rows x 25 columns]

# %%
balt = balt.drop(["Environment","Quality","Condition","Appearance","Storage",
"Crop"], axis=1)
balt.head()
# Out:
#   Commodity Name  City Name          Type       Package      Variety  \
# 0       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 1       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 2       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 3       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 4       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
#
#   Sub Variety  Grade        Date  Low Price  High Price  Mostly Low  \
# 0         NaN    NaN  04/29/2017        270       280.0         270
# 1         NaN    NaN  05/06/2017        270       280.0         270
# 2         NaN    NaN  09/24/2016        160       160.0         160
# 3         NaN    NaN  09/24/2016        160       160.0         160
# 4         NaN    NaN  11/05/2016         90       100.0          90
#
#    Mostly High    Origin  Origin District Item Size Color Unit of Sale Repack  \
# 0        280.0       NaN              NaN       lge   NaN          NaN      E
# 1        280.0       NaN              NaN       lge   NaN          NaN      E
# 2        160.0  DELAWARE              NaN       med   NaN          NaN      N
# 3        160.0  VIRGINIA              NaN       med   NaN          NaN      N
# 4        100.0  MARYLAND              NaN       lge   NaN          NaN      N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
northeast = pd.concat([balt,bos,new,phil])
northeast.shape
# Out:
# (674, 25)

# %% [markdown]
# ## Answer Some Questions
# [
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
prices = {'Low Price':['mean'],
          'High Price': ['mean']}
mprices = northeast.groupby('Unit of Sale')
mprices.agg(prices)
# Out:
#                Low Price  High Price
#                     mean        mean
# Unit of Sale
# EACH           47.916667   59.166667
# PER BIN       185.845070  206.619718
# SHELLACKED     16.000000   17.545455

# %% [markdown]
# # Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
# pumpkin_type= northeast.groupby(['Variety','City Name'])
# pumpkin_type.agg({'Commodity Name':['count']})

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
